# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plot([-2,10,13,3,5])

# %%
import numpy as num

# %%
from numpy import *

# %%
num.pi
# Out:
# 3.141592653589793

# %%
plot(randn(100))

# %% [markdown]
# #筆記

# %% [markdown]
# 分項說明
# * from numpy import (star)
# * 筆記轉換-ctrl + m + m
#
# #可以用來當標題
#
# star 可以拿來當點點 *

# %% [markdown]
# 連結
# * 中括號+東西 小括號+網址
#
# [柏睿的fb](https://www.facebook.com/)
#
# 插入圖片
# * 驚嘆號+中括號+東西 小括號+檔名
# ![ㄅㄖ帥](1.jpg)
#
# 數學符號
# * 錢符號 + 數學函式 + 錢符號
#
# $ f(x)=x^3+x^2-sin(pi)$
#
# * 兩個錢符號 會置中
#
# $$ \int_a^b f(x)\, dx$$
